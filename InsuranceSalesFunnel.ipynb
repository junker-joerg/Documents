# %%
from __future__ import print_function, division
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
df = pd.read_excel('issf061219.xlsx', skiprow=1, header=1)# 1. Zeile nicht einlesen,2. = Spaltenüberschriften
# https://databraineo.de/ki-training-resources/python/datenimport-in-python-excel-dateien-einlesen-und-schreiben/
# in SAP BW: eigenes Bookmark definiert und damit die Daten abgezogen

# %%
# alle Spalten umbenennen - 33 Spalten in der Tabelle
df.columns = [ 
    'Status',
    'Date_Forcast_Start',
    'Date_Opp_Creation',
    'EndCl_Nr', 
    'EndCl_Name', 
    'EP', 
    'Date_Opp_End', 
    'Date_Last_Change', 
    'Date_Opp_Won',
    'Debitor',
    'Debitor_name',
    'Date_Decision',
    'Date_Last_Update',
    'PC_L_3',
    'PC_L_4',
    'PC_L_5',
    'PC_L_6',
    'Sector',
    'Segment',
    'Service_Solution',
    'Solution_Cluster',
    'Solution_Line',
    'Solution',
    'Sub_Solution',
    'Opp_Nr',
    'Opp_Name',
    'TOP_Account',
    'SalesStage',
    'Recurring_Indi',
    'Anzahl_Opp',
    'EUR_NetSales',
    'EUR_Actuals',
    'FC_current_FY',
    ]

# %%
df
# Out:
#         Status Date_Forcast_Start Date_Opp_Creation    EndCl_Nr  \
# 0        Offen         17.07.2019        17.07.2019    60022731
# 1        Offen         01.08.2019        24.07.2019    60014960
# 2        Offen         07.08.2019        31.07.2019    65010594
# 3        Offen         12.08.2019        29.07.2019    60034075
# 4        Offen         15.08.2019        05.07.2019    60044840
# 5        Offen         27.08.2019        20.08.2019    60292857
# 6        Offen         30.08.2019        13.08.2019    60566900
# 7        Offen         01.09.2019        03.07.2019    60006802
# 8        Offen         01.09.2019        02.08.2019    65002338
# 9        Offen         02.09.2019        20.08.2019    60024372
# 10       Offen         03.09.2019        23.08.2019    60032757
# 11       Offen         03.09.2019        03.09.2019    60034075
# 12       Offen         04.09.2019        28.08.2019    60356221
# 13       Offen         09.09.2019        02.08.2019    60044840
# 14       Offen         15.09.2019        12.07.2019    60077928
# 15       Offen         15.09.2019        29.08.2019    60153666
# 16       Offen         16.09.2019        04.07.2019    65009487
# 17       Offen         16.09.2019        28.08.2019    60060880
# 18       Offen         25.09.2019        16.09.2019    65012808
# 19       Offen         30.09.2019        03.09.2019    60031329
# 20       Offen         01.10.2019        15.07.2019    60466854
# 21       Offen         01.10.2019        24.07.2019    60022731
# 22       Offen         01.10.2019        30.07.2019    60011706
# 23       Offen         01.10.2019        09.08.2019    60391047
# 24       Offen         01.10.2019        13.08.2019    60121105
# 25       Offen         01.10.2019        14.08.2019    60130567
# 26       Offen         01.10.2019        21.08.2019    65011381
# 27       Offen         01.10.2019        23.08.2019    60053556
# 28       Offen         01.10.2019        28.08.2019    60564696
# 29       Offen         01.10.2019        30.08.2019    60046821
# ..         ...                ...               ...         ...
# 773      Abort         18.11.2019        31.10.2019    60265904
# 774      Abort         18.11.2019        11.11.2019    60016505
# 775      Abort         25.11.2019        01.10.2019    60017065
# 776      Abort         01.12.2019        30.07.2019    60346777
# 777      Abort         01.12.2019        31.10.2019    60006802
# 777             Schäfer, Marc   31.03.2020       02.12.2019            #
# 778           Gutjahr, Gernot   31.12.2020       10.11.2019            #
# 779             Heyen, Markus   31.03.2020       09.10.2019            #
# 780  Bornhofen, Martin Castor   30.06.2020       12.11.2019            #
# 781             Hoser, Martin   31.12.2020       05.08.2019            #
# 782         Spieleder, Markus   31.12.2022       23.10.2019            #
# 783             Heyen, Markus   31.03.2020       11.10.2019            #
# 784             Heyen, Markus   31.03.2020       07.11.2019            #
# 785           Kuppler, Ulrich   31.01.2021       22.11.2019            #
# 786     Geveilers, Vjaceslavs   30.06.2020       18.10.2019            #
# 787     Geveilers, Vjaceslavs   30.06.2020       21.10.2019            #
# 788     Geveilers, Vjaceslavs   30.06.2020       21.10.2019            #
# 789             Greuel, Bernd   30.06.2020       28.11.2019            #
# 790          Baumann, Florian   30.06.2020       27.11.2019            #
# 791           Nern, Christian   30.04.2020       02.12.2019            #
# 792    Essig, Lothar Diethard   31.03.2020       13.11.2019            #
# 793          Baumann, Florian   31.12.2020       02.12.2019            #
# 794         Leiding, Jan-Eric   31.12.2020       10.10.2019            #
# 795        Hellwig, Christoph   01.04.2021       22.08.2019            #
# 796         Weddehage, Markus   31.01.2021       23.08.2019            #
# 797       Hasenburg, Christof   30.06.2021       17.09.2019            #
# 798             Stauder, Marc   30.04.2021       08.10.2019            #
# 799             Imhof, Manuel   01.01.2021       21.11.2019            #
# 800            Hansen, Roland   01.11.2022       27.09.2019            #
# 801       Oberländer, Herbert   31.01.2020       15.11.2019            #
# 802         Boetius, Frederik   31.12.2020       26.11.2019            #
#
#         Debitor  ...                              Sub_Solution    Opp_Nr  \
# 0      60022731  ...                        Legal Housekeeping  75034132
# 1      60014960  ...                   FS Core Audit Insurance  75034907
# 2      65010594  ...  Legal FS Regulatory, Compliance & Govern  75035595
# 3      60034075  ...                        Legal Housekeeping  75034846
# 4      60044840  ...                              IT-Strategie  75032816
# 5      60292857  ...                 Corporate Tax Declaration  75037563
# 6      60566900  ...                   Ind. Tax VAT Consulting  75036426
# 7      60006802  ...             Legal FS Products & Customers  75031748
# 8      65002338  ...                   FS Core Audit Insurance  75036017
# 9      60024372  ...  FS Tax Corporate Tax Advisory and Compli  75036978
# 10     60032757  ...   Legal Optimised Transaction Structuring  75038114
# 11     60034075  ...            Legal FS CHRO & Board Services  75039152
# 12     60356221  ...          FS Tax AM Reporting & Compliance  75038574
# 13     60044840  ...               FS Transformation Insurance  75036102
# 14     60077928  ...                          Nicht zugeordnet  75032693
# 15     60153666  ...             Legal FS Products & Customers  75038741
# 16     65009487  ...  Shared Service and Outsourcing Assurance  75032684
# 17     60060880  ...  Regulatory, Compliance & Governance, Whi  75038506
# 18     65012808  ...             Legal FS Products & Customers  75039149
# 19     60031329  ...   Legal Optimised Transaction Structuring  75039122
# 20     60466854  ...  Abschlussprüfung (319aHGB) [nicht kapita  75033223
# 21     60022731  ...        FS Management Consulting Insurance  75035091
# 22     60011706  ...            Cyber Response & Investigation  75034323
# 23     60391047  ...  FS Tax Corporate Tax Advisory and Compli  75036437
# 24     60121105  ...                   FS Core Audit Insurance  75036535
# 25     60130567  ...        Inbound Tax Planning / Structuring  75037182
# 26     65011381  ...             Legal FS Products & Customers  75037286
# 27     60053556  ...                   FS Core Audit Insurance  75038223
# 28     60564696  ...                         Internal Controls  75037808
# 29     65008274  ...              SAP/ ERP Finance Integration  75038783
# ..          ...  ...                                       ...       ...
# 773    60265904  ...         Tax Process & Decision Management  75044879
# 774    60016505  ...   FS IT Compliance & Information Security  75045849
# 775    60017065  ...   FS IT Compliance & Information Security  75041825
# 776    60346777  ...                   FS Transaction Services  75034848
# 777    60006802  ...  FS Risk & Finance Transformation Insuran  75044258
# 778    60046821  ...                               IT-Sourcing  75045906
# 779    60011706  ...  FS Risk & Finance Transformation Insuran  75036329
# 780  1065000359  ...  Abschlussprüfung (319aHGB) [nicht kapita  75046183
# 781    60012214  ...                          Nicht zugeordnet  75034203
# 782    60251056  ...             FS Core Processes and Systems  75037871
# 783    60047164  ...               FS Transformation Insurance  75038491
# 784    60101322  ...               FS Transformation Insurance  75034739
# 785    60072567  ...                     FS Core Audit Banking  75039407
# 786    60306336  ...  FS Risk & Finance Transformation Insuran  75043396
# 787    60306336  ...  FS Risk & Finance Transformation Insuran  75042000
# 788    60306336  ...  FS Risk & Finance Transformation Insuran  75042889
# 789    60024372  ...                  FS Actuarial / Modelling  75044733
# 790    60070003  ...                             FS CIO Agenda  75045280
# 791    60123351  ...   FS IT Compliance & Information Security  75044346
# 792    60333996  ...                  FS Compliance Management  75036562
# 793    60032757  ...             FS Core Processes and Systems  75031346
# 794    60010069  ...                                    FS M&A  75041369
# 795    65009779  ...                   FS Core Audit Insurance  75032119
# 796    60022731  ...                          Nicht zugeordnet  75036588
# 797    60046432  ...                   FS Core Audit Insurance  75035962
# 798    60034075  ...                      Compliance Assurance  75036875
# 799    60006802  ...                   FS Tax Transfer Pricing  75044388
# 800  1065000316  ...   Abschlussprüfung (319aHGB) [Corporates]  75041346
# 801    60006711  ...             FS Core Processes and Systems  75041736
# 802    60445765  ...                  FS Actuarial / Modelling  75041306
#
#                                      Opp_Name TOP_Account  \
# 0         Münchener Rückvers. - ArbR Beratung           X
# 1                   PK Hamm - Review JAP 2019           #
# 2                 Meiji Yasuda Life Insurance           #
# 3               ERGO Group AG - RFP - NVafaee           X
# 4           Swiss Life - CIO 90 Tage Programm           X
# 5                                KSA Hannover           #
# 6                HUK-Coburg Autowelt GmbH_VAT           #
# 7                 Allianz SE wegen Newsletter           X
# 8                    Markel Holdings KAP 2019           #
# 9                   WWK Tax Compliance Review           #
# 10                Allianz Technology SE_HH/AR           X
# 11              ERGO Group AG – Fremdpersonal           X
# 12        ProLog Beteiligungsgesellschaft mbH           X
# 13    OPP: VU-IT Zielbild fachlich/ technisch           X
# 14                            OVB - RPA Pilot           #
# 15    Versorgungsw. RAe NRW - regul. Beratung           #
# 16                             DGIM ISAE 3402           #
# 17        VHV Holding AG - Hinweisgebersystem           X
# 18               Accelerant Europe Ltd  UK/FF           #
# 19                       Global Finanz wg DIZ           #
# 20                     T & R Real Estate GmbH           X
# 21                       Opp: Munich Re_Cyber           X
# 22                       MSA_CBM_AlliedForces           X
# 23                  Athora_Germany_Tax Advice           #
# 24                   MR Bet. 1. GmbH JAP 2019           X
# 25                                 AON - DAC6           #
# 26                    ASSEKURATA_Legal Advice           #
# 27                           Longial JAP 2019           X
# 28   Aon Assessment GmbH – SOC Assurance 2020           #
# 29                  TBlox - 1st Level Support           X
# ..                                        ...         ...
# 773  Zurich Vers. - Implement. Impero - CS/CA           X
# 774                               PbP KZV BBV           #
# 775            Opp VKB Prüfungsbegleitung IAM           X
# 776                  Abort: Project Treehouse           #
# 777                         OPP: FT Pre-Study           X
# 778        IT Infrastructure Synergy Advisory           X
# 779                Global CoE Cyber Blueprint           X
# 780               Expleo Group AuP 31.10.2019           X
# 781   HR - IFRS 17 Impl. 2020 BT Hauptauftrag           X
# 782   OPP Design&Impl. of Market.&Sales Appl.           X
# 783  OPP: W&W_Implementierung Pega_fachl Supp           X
# 784            OPP: Zurich_Neuausrichtung CCC           X
# 785                     MEAG WPF Prüfung_2020           X
# 786      MFE Baloise IFRS 17 Gruppe 1.HJ 2020           #
# 787         MFE Baloise IFRS 17 Lokal 1.HJ 20           #
# 788        MFE Baloise IFRS 17 Gruppe_1.HJ 20           #
# 789                            Opp_SII_Themen           #
# 790    HUK-Coburg: Vorstudie Inkasso/ Exkasso           #
# 791                   Opp SwissRe Managed SOC           #
# 792  OPP:Strategy Implementation Zurich Group           X
# 793            AZ Tech: Configuration Pattern           X
# 794                     Opp_Project Goldfinch           X
# 795  Alte Oldenburger Beteiligungsgesellschaf           #
# 796       OPP:  MunichRe_Co-Sourcing Group IA           X
# 797             W&W AG KAP + Solvency II 2020           X
# 798        ERGO Group AG PS 980 Ang. GDV 2020           X
# 799            Allianz SE – HRT TP Assistance           X
# 800  ERG Barmenia Versicherungen KAP/JAP 2021           #
# 801                       Reliable Ressources           X
# 802              OPP: GDV - Treuhänderauftrag           #
#
#                              SalesStage  \
# 0                      Mündliche Zusage
# 1                      Mündliche Zusage
# 2           Opportunity Identifizierung
# 3           Opportunity Identifizierung
# 4    Angebotserstellung & Unterbreitung
# 5    Angebotserstellung & Unterbreitung
# 6            Opportunity Qualifizierung
# 7           Opportunity Identifizierung
# 8                     Vertragsabschluss
# 9    Angebotserstellung & Unterbreitung
# 10                    Lösungsdefinition
# 11          Opportunity Identifizierung
# 12           Opportunity Qualifizierung
# 13           Opportunity Qualifizierung
# 14   Angebotserstellung & Unterbreitung
# 15          Opportunity Identifizierung
# 16   Angebotserstellung & Unterbreitung
# 17   Angebotserstellung & Unterbreitung
# 18                     Lead Initiierung
# 19           Opportunity Qualifizierung
# 20      Angebots- & Vertragsverhandlung
# 21          Opportunity Identifizierung
# 22           Opportunity Qualifizierung
# 23                     Mündliche Zusage
# 24                    Vertragsabschluss
# 25                     Lead Initiierung
# 26          Opportunity Identifizierung
# 27                     Mündliche Zusage
# 28   Angebotserstellung & Unterbreitung
# 29   Angebotserstellung & Unterbreitung
# ..                                  ...
# 773                   Lösungsdefinition
# 774                    Mündliche Zusage
# 775                   Lösungsdefinition
# 776          Opportunity Qualifizierung
# 777         Opportunity Identifizierung
# 778  Angebotserstellung & Unterbreitung
# 779         Opportunity Identifizierung
# 780  Angebotserstellung & Unterbreitung
# 781                    Mündliche Zusage
# 782  Angebotserstellung & Unterbreitung
# 783  Angebotserstellung & Unterbreitung
# 784                   Lösungsdefinition
# 785                   Lösungsdefinition
# 786                    Mündliche Zusage
# 787                    Mündliche Zusage
# 788                    Mündliche Zusage
# 789         Opportunity Identifizierung
# 790          Opportunity Qualifizierung
# 791  Angebotserstellung & Unterbreitung
# 792  Angebotserstellung & Unterbreitung
# 793                   Lösungsdefinition
# 794         Opportunity Identifizierung
# 795  Angebotserstellung & Unterbreitung
# 796         Opportunity Identifizierung
# 797     Angebots- & Vertragsverhandlung
# 798  Angebotserstellung & Unterbreitung
# 799         Opportunity Identifizierung
# 800  Angebotserstellung & Unterbreitung
# 801  Angebotserstellung & Unterbreitung
# 802  Angebotserstellung & Unterbreitung
#
#                               Recurring_Indi Anzahl_Opp EUR_NetSales  \
# 0    Neu - mit Recurring Work in Folgejahren          1     30000.00
# 1               Recurring Work aus Vorjahren          1     10000.00
# 2    Neu - mit Recurring Work in Folgejahren          1     15000.00
# 3                        Neu - Einmalauftrag          1    100000.00
# 4                        Neu - Einmalauftrag          1    250000.00
# 5                        Neu - Einmalauftrag          1     20000.00
# 6    Neu - mit Recurring Work in Folgejahren          1     20000.00
# 7    Neu - mit Recurring Work in Folgejahren          1     25000.00
# 8    Neu - mit Recurring Work in Folgejahren          1     32000.00
# 9    Neu - mit Recurring Work in Folgejahren          1     50000.00
# 10                       Neu - Einmalauftrag          1     10000.00
# 11   Neu - mit Recurring Work in Folgejahren          1    150000.00
# 12   Neu - mit Recurring Work in Folgejahren          1     40000.00
# 13                       Neu - Einmalauftrag          1    400000.00
# 14                       Neu - Einmalauftrag          1     21000.00
# 15                       Neu - Einmalauftrag          1     25000.00
# 16   Neu - mit Recurring Work in Folgejahren          1     25000.00
# 17   Neu - mit Recurring Work in Folgejahren          1      5000.00
# 18                       Neu - Einmalauftrag          1     20000.00
# 19                       Neu - Einmalauftrag          1       300.00
# 20   Neu - mit Recurring Work in Folgejahren          1      4500.00
# 21                       Neu - Einmalauftrag          1     50000.00
# 22                       Neu - Einmalauftrag          1       100.00
# 23              Recurring Work aus Vorjahren          1     60000.00
# 24              Recurring Work aus Vorjahren          1     17087.77
# 25                       Neu - Einmalauftrag          1    100000.00
# 26                       Neu - Einmalauftrag          1     30000.00
# 27              Recurring Work aus Vorjahren          1     14600.00
# 28                       Neu - Einmalauftrag          1     65000.00
# 29                       Neu - Einmalauftrag          1    250000.00
# ..                                       ...        ...          ...
# 773                      Neu - Einmalauftrag          1     20000.00
# 774                      Neu - Einmalauftrag          1     35100.00
# 775                      Neu - Einmalauftrag          1    100000.00
# 776                      Neu - Einmalauftrag          1     45000.00
# 777                      Neu - Einmalauftrag          1    200000.00
# 778                      Neu - Einmalauftrag          1    300000.00
# 779                      Neu - Einmalauftrag          1    400000.00
# 780  Neu - mit Recurring Work in Folgejahren          1     50000.00
# 781                      Neu - Einmalauftrag          1   5000000.00
# 782                      Neu - Einmalauftrag          1   6120000.00
# 783                      Neu - Einmalauftrag          1    100000.00
# 784                      Neu - Einmalauftrag          1    100000.00
# 785             Recurring Work aus Vorjahren          1    250000.00
# 786             Recurring Work aus Vorjahren          1    400000.00
# 787             Recurring Work aus Vorjahren          1    440000.00
# 788             Recurring Work aus Vorjahren          1    400000.00
# 789                      Neu - Einmalauftrag          1     20000.00
# 790                      Neu - Einmalauftrag          1    240000.00
# 791                      Neu - Einmalauftrag          1     50000.00
# 792                      Neu - Einmalauftrag          1    400000.00
# 793                      Neu - Einmalauftrag          1    180000.00
# 794                      Neu - Einmalauftrag          1    190000.00
# 795  Neu - mit Recurring Work in Folgejahren          1    200000.00
# 796                      Neu - Einmalauftrag          1    125000.00
# 797             Recurring Work aus Vorjahren          1    831204.00
# 798                      Neu - Einmalauftrag          1     50000.00
# 799  Neu - mit Recurring Work in Folgejahren          1    150000.00
# 800  Neu - mit Recurring Work in Folgejahren          1    100000.00
# 801                      Neu - Einmalauftrag          1    270270.00
# 802                      Neu - Einmalauftrag          1    150000.00
#
#     EUR_Actuals FC_current_FY
# 0           0.0           NaN
# 1           0.0           NaN
# 2           0.0           NaN
# 3           0.0           NaN
# 4           0.0           NaN
# 5           0.0           NaN
# 6           0.0           NaN
# 7           0.0           NaN
# 8           0.0           NaN
# 9           0.0           NaN
# 10          0.0           NaN
# 11          0.0           NaN
# 12          0.0           NaN
# 13          0.0           NaN
# 14          0.0           NaN
# 15          0.0           NaN
# 16          0.0           NaN
# 17          0.0           NaN
# 18          0.0           NaN
# 19          0.0           NaN
# 20          0.0           NaN
# 21          0.0           NaN
# 22          0.0           NaN
# 23          0.0           NaN
# 24          0.0           NaN
# 25          0.0           NaN
# 26          0.0           NaN
# 27          0.0           NaN
# 28          0.0           NaN
# 29          0.0           NaN
# ..          ...           ...
# 773         0.0           NaN
# 774         0.0           NaN
# 775         0.0           NaN
# 776         0.0           NaN
# 777         0.0           NaN
# 778         0.0           NaN
# 779         0.0           NaN
# 780         0.0           NaN
# 781         0.0           NaN
# 782         0.0           NaN
# 783         0.0           NaN
# 784         0.0           NaN
# 785         0.0           NaN
# 786         0.0           NaN
# 787         0.0           NaN
# 788         0.0           NaN
# 789         0.0           NaN
# 790         0.0           NaN
# 791         0.0           NaN
# 792         0.0           NaN
# 793         0.0           NaN
# 794         0.0           NaN
# 795         0.0           NaN
# 796         0.0           NaN
# 797         0.0           NaN
# 798         0.0           NaN
# 799         0.0           NaN
# 800         0.0           NaN
# 801         0.0           NaN
# 802         0.0           NaN
#
# [803 rows x 33 columns]

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html

# %% [markdown]
# # Auswertung A
# 1. Summe Opps EUR Netsales
# 2. Summe Wins EUR Netsales
# 3. Durchschnittliche Winrates (%) auf EURO

# %% [raw]
# pivot_table
#
# data : DataFrame
# values : column to aggregate, optional
# index : column, Grouper, array, or list of the previous
# If an array is passed, it must be the same length as the data. The list can contain any of the other types (except list). Keys to group by on the pivot table index. If an array is passed, it is being used as the same manner as column values.
#
# columns : column, Grouper, array, or list of the previous
# If an array is passed, it must be the same length as the data. The list can contain any of the other types (except list). Keys to group by on the pivot table column. If an array is passed, it is being used as the same manner as column values.
#
# aggfunc : function, list of functions, dict, default numpy.mean
# If list of functions passed, the resulting pivot table will have hierarchical columns whose top level are the function names (inferred from the function objects themselves) If dict is passed, the key is column to aggregate and value is function or list of functions
#
# fill_value : scalar, default None
# Value to replace missing values with
#
# margins : boolean, default False
# Add all row / columns (e.g. for subtotal / grand totals)
#
# dropna : boolean, default True
# Do not include columns whose entries are all NaN
#
# margins_name : string, default ‘All’
# Name of the row / column that will contain the totals when margins is True.
#
# observed : boolean, default False
# This only applies if any of the groupers are Categoricals. If True: only show observed values for categorical groupers. If False: show all values for categorical groupers.
#
# Changed in version 0.25.0.

# %% [markdown]
# ![Auswertung_A.JPG](attachment:Auswertung_A.JPG)

# %%
#pivot_table = pd.pivot_table(df)

# %%
(df['Date_Opp_Creation'])
# Out:
# 0      17.07.2019
# 1      24.07.2019
# 2      31.07.2019
# 3      29.07.2019
# 4      05.07.2019
# 5      20.08.2019
# 6      13.08.2019
# 7      03.07.2019
# 8      02.08.2019
# 9      20.08.2019
# 10     23.08.2019
# 11     03.09.2019
# 12     28.08.2019
# 13     02.08.2019
# 14     12.07.2019
# 15     29.08.2019
# 16     04.07.2019
# 17     28.08.2019
# 18     16.09.2019
# 19     03.09.2019
# 20     15.07.2019
# 21     24.07.2019
# 22     30.07.2019
# 23     09.08.2019
# 24     13.08.2019
# 25     14.08.2019
# 26     21.08.2019
# 27     23.08.2019
# 28     28.08.2019
# 29     30.08.2019
#           ...
# 773    31.10.2019
# 774    11.11.2019
# 775    01.10.2019
# 776    30.07.2019
# 777    31.10.2019
# 778    10.11.2019
# 779    06.08.2019
# 780    11.11.2019
# 781    16.07.2019
# 782    21.08.2019
# 783    27.08.2019
# 784    30.08.2019
# 785    10.09.2019
# 786    18.10.2019
# 787    18.10.2019
# 788    18.10.2019
# 789    04.11.2019
# 790    20.11.2019
# 791    31.10.2019
# 792    19.09.2019
# 793    03.07.2019
# 794    01.10.2019
# 795    10.07.2019
# 796    23.08.2019
# 797    05.08.2019
# 798    15.08.2019
# 799    28.10.2019
# 800    27.09.2019
# 801    02.10.2019
# 802    26.09.2019
# Name: Date_Opp_Creation, Length: 803, dtype: object

# %%
plt.plot(df['Date_Opp_Creation'])

# %%
pd.options.display.float_format = 'EUR {:,.2f}'.format
# Änderung des Anzeigeformats für die Zahlen im Dataframe
# Das geht so nur mäßig, da dann das Datum / String-Anzeigen
# nicht mehr funktioniert

# %%
pd.pivot_table(df,index=['Service_Solution'],values=['EUR_NetSales'])
# Out:
#                      EUR_NetSales
# Service_Solution
# Audit               EUR 48,166.23
# Consulting         EUR 145,756.68
# Deal Advisory      EUR 116,435.05
# Financial Services EUR 129,705.46
# Law                EUR 253,000.27
# Nicht zugeordnet   EUR 359,149.83
# Tax                 EUR 55,360.00

# %%
df[('EUR_NetSales')].sum() / 1000000 # 108 Mio ... das stimmt wohl
# Out:
# 108.87774734

# %%
grouped = df.groupby(['Service_Solution'])

# %%
grouped.sum()
# Out:
#                        EndCl_Nr      Debitor       Opp_Nr  Anzahl_Opp  \
# Service_Solution
# Audit                5562713978   5562622570   3151719398          42
# Consulting           2962969324   2962971814   3676985621          49
# Deal Advisory        1202160883   1202160883   1500822095          20
# Financial Services  40399279297  40394056419  38870591033         508
# Law                  4495674723   4489839533   5552935493          74
# Nicht zugeordnet     1441156583   1441156583   1800987491          24
# Tax                  4622324948   4611303973   5702910397          75
#
#                         EUR_NetSales      EUR_Actuals     FC_current_FY
# Service_Solution
# Audit               EUR 2,022,981.50   EUR 319,643.95    EUR 453,581.99
# Consulting          EUR 7,142,077.36   EUR 640,125.00  EUR 1,552,605.11
# Deal Advisory       EUR 2,328,701.00    EUR 91,452.50    EUR 410,929.00
# Financial Services EUR 65,890,371.48 EUR 4,306,015.90 EUR 22,670,854.53
# Law                EUR 18,722,020.00   EUR 681,197.06    EUR 597,162.91
# Nicht zugeordnet    EUR 8,619,596.00         EUR 0.00    EUR 352,500.00
# Tax                 EUR 4,152,000.00   EUR 358,369.10  EUR 1,013,318.36

# %%
grouped1 = df.groupby(['Date_Opp_Won'])
grouped1.sum()
df3 = grouped1.sum()
df3.sort_values(by = ['EUR_NetSales'])
# Out:
#                  EndCl_Nr      Debitor       Opp_Nr  Anzahl_Opp  \
# Date_Opp_Won
# 19.09.2019      120094329    120094329    150072495           2
# 12.08.2019      181025306    181025306    225106591           3
# 25.07.2019       60572887     60144260     75034888           1
# 10.08.2019       65002689     65002689     75035214           1
# 13.11.2019       60010618     60010618     75044941           1
# 29.07.2019       60479250     60479250     75035381           1
# 04.11.2019       60121558     60306336     75045165           1
# 13.09.2019       60509707     60509707     75038109           1
# 12.07.2019       60478768     60478768     75032358           1
# 31.10.2019      120322070    120122007    150088194           2
# 24.07.2019      120491087    120491087    150067674           2
# 15.09.2019       60104167     60104167     75039538           1
# 23.07.2019       60572842     60572842     75032755           1
# 06.08.2019       60063429     60063429     75030825           1
# 09.07.2019      125060194    120060631    150063783           2
# 06.09.2019      130022192    130022192    150074572           2
# 15.07.2019       60563505     60570470     75033875           1
# 02.10.2019      120165047    120165047    150082851           2
# 21.11.2019      120513330    120513330    150082300           2
# 09.09.2019       60035358     60035358     75034615           1
# 05.07.2019      120096350    120096350    150064099           2
# 17.07.2019       60007885     60007885     75032881           1
# 25.10.2019       60048153     60048153     75042997           1
# 26.09.2019      120399561    120399561    150080019           2
# 23.08.2019      185188781    185041780    225105520           3
# 05.09.2019      120180239    120180239    150073043           2
# 05.08.2019      121130076    121130076    150068860           2
# 01.10.2019      120039559    120039559    150076854           2
# 21.08.2019    EUR 1,770,300.00   EUR 169,828.00    EUR 874,054.01
# #            EUR 89,109,329.88         EUR 0.00 EUR 16,524,865.41
#
# [103 rows x 7 columns]

# %%
print(df3[('Debitor')])
# Out:
# Date_Opp_Won
# #             31697936600
# 01.08.2019       60011591
# 01.10.2019      120039559
# 02.09.2019      120046643
# 02.10.2019      120165047
# 02.12.2019      185348685
# 03.08.2019       60010069
# 03.12.2019      486067659
# 04.09.2019     1180521859
# 04.10.2019      240115474
# 04.11.2019       60306336
# 04.12.2019      120068115
# 05.07.2019      120096350
# 05.08.2019      121130076
# 05.09.2019      120180239
# 05.11.2019      300390495
# 05.12.2019      310259935
# 06.08.2019       60063429
# 06.09.2019      130022192
# 06.11.2019      185031635
# 07.08.2019      300351550
# 07.10.2019      301173484
# 07.11.2019      180081887
# 08.08.2019      305110916
# 08.10.2019     1023709580
# 08.11.2019      485436713
# 09.07.2019      120060631
# 09.08.2019      246516381
# 09.09.2019       60035358
# 09.10.2019       60092919
#                  ...
# 22.08.2019      240638554
# 22.10.2019      180750323
# 22.11.2019       60109914
# 23.07.2019       60572842
# 23.08.2019      185041780
# 23.09.2019      120177048
# 23.10.2019      125613092
# 24.07.2019      120491087
# 24.09.2019      120123837
# 24.10.2019      301667725
# 25.07.2019       60144260
# 25.10.2019       60048153
# 25.11.2019      245064071
# 26.07.2019      245139181
# 26.08.2019      120102646
# 26.09.2019      120399561
# 26.11.2019      180073897
# 27.08.2019      240687116
# 27.09.2019      665293118
# 27.11.2019      425580714
# 28.08.2019      480971855
# 28.10.2019      125045690
# 28.11.2019      300993887
# 29.07.2019       60479250
# 29.10.2019      360721426
# 30.07.2019      120185760
# 30.08.2019      180388768
# 30.09.2019     1120114401
# 30.10.2019      180464245
# 31.10.2019      120122007
# Name: Debitor, Length: 103, dtype: int64

# %%
# %gui

# %%
# %pylab
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib

# %%
df['EUR_NetSales']
# Out:
# 0        EUR 30,000.00
# 1        EUR 10,000.00
# 2        EUR 15,000.00
# 3       EUR 100,000.00
# 4       EUR 250,000.00
# 5        EUR 20,000.00
# 6        EUR 20,000.00
# 7        EUR 25,000.00
# 8        EUR 32,000.00
# 9        EUR 50,000.00
# 10       EUR 10,000.00
# 11      EUR 150,000.00
# 12       EUR 40,000.00
# 13      EUR 400,000.00
# 14       EUR 21,000.00
# 15       EUR 25,000.00
# 16       EUR 25,000.00
# 17        EUR 5,000.00
# 18       EUR 20,000.00
# 19          EUR 300.00
# 20        EUR 4,500.00
# 21       EUR 50,000.00
# 22          EUR 100.00
# 23       EUR 60,000.00
# 24       EUR 17,087.77
# 25      EUR 100,000.00
# 26       EUR 30,000.00
# 27       EUR 14,600.00
# 28       EUR 65,000.00
# 29      EUR 250,000.00
#             ...
# 773      EUR 20,000.00
# 774      EUR 35,100.00
# 775     EUR 100,000.00
# 776      EUR 45,000.00
# 777     EUR 200,000.00
# 778     EUR 300,000.00
# 779     EUR 400,000.00
# 780      EUR 50,000.00
# 781   EUR 5,000,000.00
# 782   EUR 6,120,000.00
# 783     EUR 100,000.00
# 784     EUR 100,000.00
# 785     EUR 250,000.00
# 786     EUR 400,000.00
# 787     EUR 440,000.00
# 788     EUR 400,000.00
# 789      EUR 20,000.00
# 790     EUR 240,000.00
# 791      EUR 50,000.00
# 792     EUR 400,000.00
# 793     EUR 180,000.00
# 794     EUR 190,000.00
# 795     EUR 200,000.00
# 796     EUR 125,000.00
# 797     EUR 831,204.00
# 798      EUR 50,000.00
# 799     EUR 150,000.00
# 800     EUR 100,000.00
# 801     EUR 270,270.00
# 802     EUR 150,000.00
# Name: EUR_NetSales, Length: 803, dtype: float64

# %%
df.dtypes # ToDo: Datentypen für die Berechungen anpassen - aber
# schon direkt nach dem laden...
# Out:
# Status                 object
# Date_Forcast_Start     object
# Date_Opp_Creation      object
# EndCl_Nr                int64
# EndCl_Name             object
# EP                     object
# Date_Opp_End           object
# Date_Last_Change       object
# Date_Opp_Won           object
# Debitor                 int64
# Debitor_name           object
# Date_Decision          object
# Date_Last_Update       object
# PC_L_3                 object
# PC_L_4                 object
# PC_L_5                 object
# PC_L_6                 object
# Sector                 object
# Segment                object
# Service_Solution       object
# Solution_Cluster       object
# Solution_Line          object
# Solution               object
# Sub_Solution           object
# Opp_Nr                  int64
# Opp_Name               object
# TOP_Account            object
# SalesStage             object
# Recurring_Indi         object
# Anzahl_Opp              int64
# EUR_NetSales          float64
# EUR_Actuals           float64
# FC_current_FY         float64
# dtype: object

# %%
s = df['PC_L_3'].to_string()
df['PC_L_3'] = s

# %%
df.dtypes
# Out:
# Status                 object
# Date_Forcast_Start     object
# Date_Opp_Creation      object
# EndCl_Nr                int64
# EndCl_Name             object
# EP                     object
# Date_Opp_End           object
# Date_Last_Change       object
# Date_Opp_Won           object
# Debitor                 int64
# Debitor_name           object
# Date_Decision          object
# Date_Last_Update       object
# PC_L_3                 object
# PC_L_4                 object
# PC_L_5                 object
# PC_L_6                 object
# Sector                 object
# Segment                object
# Service_Solution       object
# Solution_Cluster       object
# Solution_Line          object
# Solution               object
# Sub_Solution           object
# Opp_Nr                  int64
# Opp_Name               object
# TOP_Account            object
# SalesStage             object
# Recurring_Indi         object
# Anzahl_Opp              int64
# EUR_NetSales          float64
# EUR_Actuals           float64
# FC_current_FY         float64
# dtype: object

# %%
df
# Out:
#         Status Date_Forcast_Start Date_Opp_Creation    EndCl_Nr  \
# 0        Offen         17.07.2019        17.07.2019    60022731
# 1        Offen         01.08.2019        24.07.2019    60014960
# 2        Offen         07.08.2019        31.07.2019    65010594
# 3        Offen         12.08.2019        29.07.2019    60034075
# 4        Offen         15.08.2019        05.07.2019    60044840
# 5        Offen         27.08.2019        20.08.2019    60292857
# 6        Offen         30.08.2019        13.08.2019    60566900
# 7        Offen         01.09.2019        03.07.2019    60006802
# 8        Offen         01.09.2019        02.08.2019    65002338
# 9        Offen         02.09.2019        20.08.2019    60024372
# 10       Offen         03.09.2019        23.08.2019    60032757
# 2      65010594  ...  Legal FS Regulatory, Compliance & Govern  75035595
# 3      60034075  ...                        Legal Housekeeping  75034846
# 4      60044840  ...                              IT-Strategie  75032816
# 5      60292857  ...                 Corporate Tax Declaration  75037563
# 6      60566900  ...                   Ind. Tax VAT Consulting  75036426
# 7      60006802  ...             Legal FS Products & Customers  75031748
# 8      65002338  ...                   FS Core Audit Insurance  75036017
# 9      60024372  ...  FS Tax Corporate Tax Advisory and Compli  75036978
# 10     60032757  ...   Legal Optimised Transaction Structuring  75038114
# 11     60034075  ...            Legal FS CHRO & Board Services  75039152
# 12     60356221  ...          FS Tax AM Reporting & Compliance  75038574
# 13     60044840  ...               FS Transformation Insurance  75036102
# 14     60077928  ...                          Nicht zugeordnet  75032693
# 15     60153666  ...             Legal FS Products & Customers  75038741
# 16     65009487  ...  Shared Service and Outsourcing Assurance  75032684
# 17     60060880  ...  Regulatory, Compliance & Governance, Whi  75038506
# 18     65012808  ...             Legal FS Products & Customers  75039149
# 19     60031329  ...   Legal Optimised Transaction Structuring  75039122
# 20     60466854  ...  Abschlussprüfung (319aHGB) [nicht kapita  75033223
# 21     60022731  ...        FS Management Consulting Insurance  75035091
# 22     60011706  ...            Cyber Response & Investigation  75034323
# 23     60391047  ...  FS Tax Corporate Tax Advisory and Compli  75036437
# 24     60121105  ...                   FS Core Audit Insurance  75036535
# 25     60130567  ...        Inbound Tax Planning / Structuring  75037182
# 26     65011381  ...             Legal FS Products & Customers  75037286
# 27     60053556  ...                   FS Core Audit Insurance  75038223
# 28     60564696  ...                         Internal Controls  75037808
# 29     65008274  ...              SAP/ ERP Finance Integration  75038783
# ..          ...  ...                                       ...       ...
# 773    60265904  ...         Tax Process & Decision Management  75044879
# 774    60016505  ...   FS IT Compliance & Information Security  75045849
# 775    60017065  ...   FS IT Compliance & Information Security  75041825
# 776    60346777  ...                   FS Transaction Services  75034848
# 777    60006802  ...  FS Risk & Finance Transformation Insuran  75044258
# 778    60046821  ...                               IT-Sourcing  75045906
# 779    60011706  ...  FS Risk & Finance Transformation Insuran  75036329
# 780  1065000359  ...  Abschlussprüfung (319aHGB) [nicht kapita  75046183
# 781    60012214  ...                          Nicht zugeordnet  75034203
# 782    60251056  ...             FS Core Processes and Systems  75037871
# 783    60047164  ...               FS Transformation Insurance  75038491
# 784    60101322  ...               FS Transformation Insurance  75034739
# 785    60072567  ...                     FS Core Audit Banking  75039407
# 786    60306336  ...  FS Risk & Finance Transformation Insuran  75043396
# 787    60306336  ...  FS Risk & Finance Transformation Insuran  75042000
# 788    60306336  ...  FS Risk & Finance Transformation Insuran  75042889
# 789    60024372  ...                  FS Actuarial / Modelling  75044733
# 790    60070003  ...                             FS CIO Agenda  75045280
# 791    60123351  ...   FS IT Compliance & Information Security  75044346
# 792    60333996  ...                  FS Compliance Management  75036562
# 793    60032757  ...             FS Core Processes and Systems  75031346
# 794    60010069  ...                                    FS M&A  75041369
# 795    65009779  ...                   FS Core Audit Insurance  75032119
# 796    60022731  ...                          Nicht zugeordnet  75036588
# 797    60046432  ...                   FS Core Audit Insurance  75035962
# 798    60034075  ...                      Compliance Assurance  75036875
# 799    60006802  ...                   FS Tax Transfer Pricing  75044388
# 800  1065000316  ...   Abschlussprüfung (319aHGB) [Corporates]  75041346
# 801    60006711  ...             FS Core Processes and Systems  75041736
# 802    60445765  ...                  FS Actuarial / Modelling  75041306
#
#                                      Opp_Name TOP_Account  \
# 0         Münchener Rückvers. - ArbR Beratung           X
# 1                   PK Hamm - Review JAP 2019           #
# 2                 Meiji Yasuda Life Insurance           #
# 3               ERGO Group AG - RFP - NVafaee           X
# 4           Swiss Life - CIO 90 Tage Programm           X
# 5                                KSA Hannover           #
# 6                HUK-Coburg Autowelt GmbH_VAT           #
# 7                 Allianz SE wegen Newsletter           X
# 8                    Markel Holdings KAP 2019           #
# 9                   WWK Tax Compliance Review           #
# 10                Allianz Technology SE_HH/AR           X
# 11              ERGO Group AG – Fremdpersonal           X
# 12        ProLog Beteiligungsgesellschaft mbH           X
# 13    OPP: VU-IT Zielbild fachlich/ technisch           X
# 14                            OVB - RPA Pilot           #
# 15    Versorgungsw. RAe NRW - regul. Beratung           #
# 16                             DGIM ISAE 3402           #
# 17        VHV Holding AG - Hinweisgebersystem           X
# 18               Accelerant Europe Ltd  UK/FF           #
# 19                       Global Finanz wg DIZ           #
# 20                     T & R Real Estate GmbH           X
# 21                       Opp: Munich Re_Cyber           X
# 22                       MSA_CBM_AlliedForces           X
# 23                  Athora_Germany_Tax Advice           #
# 24                   MR Bet. 1. GmbH JAP 2019           X
# 25                                 AON - DAC6           #
# 26                    ASSEKURATA_Legal Advice           #
# 27                           Longial JAP 2019           X
# 28   Aon Assessment GmbH – SOC Assurance 2020           #
# 29                  TBlox - 1st Level Support           X
# ..                                        ...         ...
# 773  Zurich Vers. - Implement. Impero - CS/CA           X
# 774                               PbP KZV BBV           #
# 775            Opp VKB Prüfungsbegleitung IAM           X
# 776                  Abort: Project Treehouse           #
# 777                         OPP: FT Pre-Study           X
# 778        IT Infrastructure Synergy Advisory           X
# 779                Global CoE Cyber Blueprint           X
# 780               Expleo Group AuP 31.10.2019           X
# 781   HR - IFRS 17 Impl. 2020 BT Hauptauftrag           X
# 782   OPP Design&Impl. of Market.&Sales Appl.           X
# 783  OPP: W&W_Implementierung Pega_fachl Supp           X
# 784            OPP: Zurich_Neuausrichtung CCC           X
# 785                     MEAG WPF Prüfung_2020           X
# 786      MFE Baloise IFRS 17 Gruppe 1.HJ 2020           #
# 787         MFE Baloise IFRS 17 Lokal 1.HJ 20           #
# 788        MFE Baloise IFRS 17 Gruppe_1.HJ 20           #
# 789                            Opp_SII_Themen           #
# 790    HUK-Coburg: Vorstudie Inkasso/ Exkasso           #
# 791                   Opp SwissRe Managed SOC           #
# 792  OPP:Strategy Implementation Zurich Group           X
# 793            AZ Tech: Configuration Pattern           X
# 794                     Opp_Project Goldfinch           X
# 795  Alte Oldenburger Beteiligungsgesellschaf           #
# 796       OPP:  MunichRe_Co-Sourcing Group IA           X
# 797             W&W AG KAP + Solvency II 2020           X
# 798        ERGO Group AG PS 980 Ang. GDV 2020           X
# 799            Allianz SE – HRT TP Assistance           X
# 800  ERG Barmenia Versicherungen KAP/JAP 2021           #
# 801                       Reliable Ressources           X
# 802              OPP: GDV - Treuhänderauftrag           #
#
#                              SalesStage  \
# 0                      Mündliche Zusage
# 1                      Mündliche Zusage
# 2           Opportunity Identifizierung
# 3           Opportunity Identifizierung
# 4    Angebotserstellung & Unterbreitung
# 5    Angebotserstellung & Unterbreitung
# 6            Opportunity Qualifizierung
# 7           Opportunity Identifizierung
# 8                     Vertragsabschluss
# 9    Angebotserstellung & Unterbreitung
# 10                    Lösungsdefinition
# 11          Opportunity Identifizierung
# 12           Opportunity Qualifizierung
# 13           Opportunity Qualifizierung
# 14   Angebotserstellung & Unterbreitung
# 15          Opportunity Identifizierung
# 16   Angebotserstellung & Unterbreitung
# 17   Angebotserstellung & Unterbreitung
# 18                     Lead Initiierung
# 19           Opportunity Qualifizierung
# 20      Angebots- & Vertragsverhandlung
# 21          Opportunity Identifizierung
# 22           Opportunity Qualifizierung
# 23                     Mündliche Zusage
# 24                    Vertragsabschluss
# 25                     Lead Initiierung
# 26          Opportunity Identifizierung
# 27                     Mündliche Zusage
# 28   Angebotserstellung & Unterbreitung
# 29   Angebotserstellung & Unterbreitung
# ..                                  ...
# 773                   Lösungsdefinition
# 774                    Mündliche Zusage
# 775                   Lösungsdefinition
# 776          Opportunity Qualifizierung
# 777         Opportunity Identifizierung
# 778  Angebotserstellung & Unterbreitung
# 779         Opportunity Identifizierung
# 780  Angebotserstellung & Unterbreitung
# 781                    Mündliche Zusage
# 782  Angebotserstellung & Unterbreitung
# 783  Angebotserstellung & Unterbreitung
# 784                   Lösungsdefinition
# 785                   Lösungsdefinition
# 786                    Mündliche Zusage
# 787                    Mündliche Zusage
# 788                    Mündliche Zusage
# 789         Opportunity Identifizierung
# 790          Opportunity Qualifizierung
# 791  Angebotserstellung & Unterbreitung
# 792  Angebotserstellung & Unterbreitung
# 793                   Lösungsdefinition
# 794         Opportunity Identifizierung
# 795  Angebotserstellung & Unterbreitung
# 796         Opportunity Identifizierung
# 797     Angebots- & Vertragsverhandlung
# 798  Angebotserstellung & Unterbreitung
# 799         Opportunity Identifizierung
# 800  Angebotserstellung & Unterbreitung
# 801  Angebotserstellung & Unterbreitung
# 802  Angebotserstellung & Unterbreitung
#
#                               Recurring_Indi Anzahl_Opp     EUR_NetSales  \
# 0    Neu - mit Recurring Work in Folgejahren          1    EUR 30,000.00
# 1               Recurring Work aus Vorjahren          1    EUR 10,000.00
# 2    Neu - mit Recurring Work in Folgejahren          1    EUR 15,000.00
# 3                        Neu - Einmalauftrag          1   EUR 100,000.00
# 4                        Neu - Einmalauftrag          1   EUR 250,000.00
# 5                        Neu - Einmalauftrag          1    EUR 20,000.00
# 6    Neu - mit Recurring Work in Folgejahren          1    EUR 20,000.00
# 7    Neu - mit Recurring Work in Folgejahren          1    EUR 25,000.00
# 8    Neu - mit Recurring Work in Folgejahren          1    EUR 32,000.00
# 9    Neu - mit Recurring Work in Folgejahren          1    EUR 50,000.00
# 10                       Neu - Einmalauftrag          1    EUR 10,000.00
# 11   Neu - mit Recurring Work in Folgejahren          1   EUR 150,000.00
# 12   Neu - mit Recurring Work in Folgejahren          1    EUR 40,000.00
# 13                       Neu - Einmalauftrag          1   EUR 400,000.00
# 14                       Neu - Einmalauftrag          1    EUR 21,000.00
# 15                       Neu - Einmalauftrag          1    EUR 25,000.00
# 16   Neu - mit Recurring Work in Folgejahren          1    EUR 25,000.00
# 17   Neu - mit Recurring Work in Folgejahren          1     EUR 5,000.00
# 18                       Neu - Einmalauftrag          1    EUR 20,000.00
# 19                       Neu - Einmalauftrag          1       EUR 300.00
# 20   Neu - mit Recurring Work in Folgejahren          1     EUR 4,500.00
# 21                       Neu - Einmalauftrag          1    EUR 50,000.00
# 22                       Neu - Einmalauftrag          1       EUR 100.00
# 23              Recurring Work aus Vorjahren          1    EUR 60,000.00
# 24              Recurring Work aus Vorjahren          1    EUR 17,087.77
# 25                       Neu - Einmalauftrag          1   EUR 100,000.00
# 26                       Neu - Einmalauftrag          1    EUR 30,000.00
# 27              Recurring Work aus Vorjahren          1    EUR 14,600.00
# 28                       Neu - Einmalauftrag          1    EUR 65,000.00
# 29                       Neu - Einmalauftrag          1   EUR 250,000.00
# ..                                       ...        ...              ...
# 773                      Neu - Einmalauftrag          1    EUR 20,000.00
# 774                      Neu - Einmalauftrag          1    EUR 35,100.00
# 775                      Neu - Einmalauftrag          1   EUR 100,000.00
# 776                      Neu - Einmalauftrag          1    EUR 45,000.00
# 777                      Neu - Einmalauftrag          1   EUR 200,000.00
# 778                      Neu - Einmalauftrag          1   EUR 300,000.00
# 779                      Neu - Einmalauftrag          1   EUR 400,000.00
# 780  Neu - mit Recurring Work in Folgejahren          1    EUR 50,000.00
# 781                      Neu - Einmalauftrag          1 EUR 5,000,000.00
# 782                      Neu - Einmalauftrag          1 EUR 6,120,000.00
# 783                      Neu - Einmalauftrag          1   EUR 100,000.00
# 784                      Neu - Einmalauftrag          1   EUR 100,000.00
# 785             Recurring Work aus Vorjahren          1   EUR 250,000.00
# 786             Recurring Work aus Vorjahren          1   EUR 400,000.00
# 787             Recurring Work aus Vorjahren          1   EUR 440,000.00
# 788             Recurring Work aus Vorjahren          1   EUR 400,000.00
# 789                      Neu - Einmalauftrag          1    EUR 20,000.00
# 790                      Neu - Einmalauftrag          1   EUR 240,000.00
# 791                      Neu - Einmalauftrag          1    EUR 50,000.00
# 792                      Neu - Einmalauftrag          1   EUR 400,000.00
# 793                      Neu - Einmalauftrag          1   EUR 180,000.00
# 794                      Neu - Einmalauftrag          1   EUR 190,000.00
# 795  Neu - mit Recurring Work in Folgejahren          1   EUR 200,000.00
# 796                      Neu - Einmalauftrag          1   EUR 125,000.00
# 797             Recurring Work aus Vorjahren          1   EUR 831,204.00
# 798                      Neu - Einmalauftrag          1    EUR 50,000.00
# 799  Neu - mit Recurring Work in Folgejahren          1   EUR 150,000.00
# 800  Neu - mit Recurring Work in Folgejahren          1   EUR 100,000.00
# 801                      Neu - Einmalauftrag          1   EUR 270,270.00
# 802                      Neu - Einmalauftrag          1   EUR 150,000.00
#
#     EUR_Actuals FC_current_FY
# 0      EUR 0.00       EUR nan
# 1      EUR 0.00       EUR nan
# 2      EUR 0.00       EUR nan
# 3      EUR 0.00       EUR nan
# 4      EUR 0.00       EUR nan
# 5      EUR 0.00       EUR nan
# 6      EUR 0.00       EUR nan
# 7      EUR 0.00       EUR nan
# 8      EUR 0.00       EUR nan
# 9      EUR 0.00       EUR nan
# 10     EUR 0.00       EUR nan
# 11     EUR 0.00       EUR nan
# 12     EUR 0.00       EUR nan
# 13     EUR 0.00       EUR nan
# 14     EUR 0.00       EUR nan
# 15     EUR 0.00       EUR nan
# 16     EUR 0.00       EUR nan
# 17     EUR 0.00       EUR nan
# 18     EUR 0.00       EUR nan
# 19     EUR 0.00       EUR nan
# 20     EUR 0.00       EUR nan
# 21     EUR 0.00       EUR nan
# 22     EUR 0.00       EUR nan
# 23     EUR 0.00       EUR nan
# 24     EUR 0.00       EUR nan
# 25     EUR 0.00       EUR nan
# 26     EUR 0.00       EUR nan
# 27     EUR 0.00       EUR nan
# 28     EUR 0.00       EUR nan
# 29     EUR 0.00       EUR nan
# ..          ...           ...
# 773    EUR 0.00       EUR nan
# 774    EUR 0.00       EUR nan
# 775    EUR 0.00       EUR nan
# 776    EUR 0.00       EUR nan
# 777    EUR 0.00       EUR nan
# 778    EUR 0.00       EUR nan
# 779    EUR 0.00       EUR nan
# 780    EUR 0.00       EUR nan
# 781    EUR 0.00       EUR nan
# 782    EUR 0.00       EUR nan
# 783    EUR 0.00       EUR nan
# 784    EUR 0.00       EUR nan
# 785    EUR 0.00       EUR nan
# 786    EUR 0.00       EUR nan
# 787    EUR 0.00       EUR nan
# 788    EUR 0.00       EUR nan
# 789    EUR 0.00       EUR nan
# 790    EUR 0.00       EUR nan
# 791    EUR 0.00       EUR nan
# 792    EUR 0.00       EUR nan
# 793    EUR 0.00       EUR nan
# 794    EUR 0.00       EUR nan
# 795    EUR 0.00       EUR nan
# 796    EUR 0.00       EUR nan
# 797    EUR 0.00       EUR nan
# 798    EUR 0.00       EUR nan
# 799    EUR 0.00       EUR nan
# 800    EUR 0.00       EUR nan
# 801    EUR 0.00       EUR nan
# 802    EUR 0.00       EUR nan
#
# [803 rows x 33 columns]

# %%
pd.describe_option('display')
# Out:
# display.chop_threshold : float or None
#     if set to a float value, all float values smaller then the given threshold
#     will be displayed as exactly 0 by repr and friends.
#     [default: None] [currently: None]
#
# display.colheader_justify : 'left'/'right'
#     Controls the justification of column headers. used by DataFrameFormatter.
#     [default: right] [currently: right]
#
# display.column_space No description available.
#     [default: 12] [currently: 12]
#
# display.date_dayfirst : boolean
#     When True, prints and parses dates with the day first, eg 20/01/2005
#     [default: False] [currently: False]
#
# display.date_yearfirst : boolean
#     When True, prints and parses dates with the year first, eg 2005/01/20
#     [default: False] [currently: False]
#
# display.encoding : str/unicode
#     Defaults to the detected encoding of the console.
#     Specifies the encoding to be used for strings returned by to_string,
#     these are generally strings meant to be displayed on the console.
#     [default: UTF-8] [currently: UTF-8]
#
# display.expand_frame_repr : boolean
#     Whether to print out the full DataFrame repr for wide DataFrames across
#     multiple lines, `max_columns` is still respected, but the output will
#     wrap-around across multiple "pages" if its width exceeds `display.width`.
#     [default: True] [currently: True]
#
# display.float_format : callable
#     The callable should accept a floating point number and return
#     a string with the desired format of the number. This is used
#     in some places like SeriesFormatter.
#     See formats.format.EngFormatter for an example.
#     [default: None] [currently: <built-in method format of str object at 0x135c27d30>]
#
# display.html.border : int
#     A ``border=value`` attribute is inserted in the ``<table>`` tag
#     for the DataFrame HTML repr.
#     [default: 1] [currently: 1]
#
# display.html.table_schema : boolean
#     Whether to publish a Table Schema representation for frontends
#     that support it.
#     (default: False)
#     [default: False] [currently: False]
#
# display.html.use_mathjax : boolean
#     When True, Jupyter notebook will process table contents using MathJax,
#     rendering mathematical expressions enclosed by the dollar symbol.
#     (default: True)
#     [default: True] [currently: True]
#
# display.large_repr : 'truncate'/'info'
#     For DataFrames exceeding max_rows/max_cols, the repr (and HTML repr) can
#     show a truncated table (the default from 0.13), or switch to the view from
#     df.info() (the behaviour in earlier versions of pandas).
#     [default: truncate] [currently: truncate]
#
# display.latex.escape : bool
#     This specifies if the to_latex method of a Dataframe uses escapes special
#     characters.
#     Valid values: False,True
#     [default: True] [currently: True]
#
# display.latex.longtable :bool
#     This specifies if the to_latex method of a Dataframe uses the longtable
#     format.
#     Valid values: False,True
#     [default: False] [currently: False]
#
# display.latex.multicolumn : bool
#     This specifies if the to_latex method of a Dataframe uses multicolumns
#     to pretty-print MultiIndex columns.
#     Valid values: False,True
#     [default: True] [currently: True]
#
# display.latex.multicolumn_format : bool
#     This specifies if the to_latex method of a Dataframe uses multicolumns
#     to pretty-print MultiIndex columns.
#     Valid values: False,True
#     [default: l] [currently: l]
#
# display.latex.multirow : bool
#     This specifies if the to_latex method of a Dataframe uses multirows
#     to pretty-print MultiIndex rows.
#     Valid values: False,True
#     [default: False] [currently: False]
#
# display.latex.repr : boolean
#     Whether to produce a latex DataFrame representation for jupyter
#     environments that support it.
#     (default: False)
#     [default: False] [currently: False]
#
# display.max_categories : int
#     This sets the maximum number of categories pandas should output when
#     printing out a `Categorical` or a Series of dtype "category".
#     [default: 8] [currently: 8]
#
# display.max_columns : int
#     If max_cols is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the width of the terminal and print a truncated object which fits
#     the screen width. The IPython notebook, IPython qtconsole, or IDLE
#     do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 20] [currently: 20]
#
# display.max_colwidth : int
#     The maximum width in characters of a column in the repr of
#     a pandas data structure. When the column overflows, a "..."
#     placeholder is embedded in the output.
#     [default: 50] [currently: 50]
#
# display.max_info_columns : int
#     max_info_columns is used in DataFrame.info method to decide if
#     per column information will be printed.
#     [default: 100] [currently: 100]
#
# display.max_info_rows : int or None
#     df.info() will usually show null-counts for each column.
#     For large frames this can be quite slow. max_info_rows and max_info_cols
#     limit this null check only to frames with smaller dimensions than
#     specified.
#     [default: 1690785] [currently: 1690785]
#
# display.max_rows : int
#     If max_rows is exceeded, switch to truncate view. Depending on
#     `large_repr`, objects are either centrally truncated or printed as
#     a summary view. 'None' value means unlimited.
#
#     In case python/IPython is running in a terminal and `large_repr`
#     equals 'truncate' this can be set to 0 and pandas will auto-detect
#     the height of the terminal and print a truncated object which fits
#     the screen height. The IPython notebook, IPython qtconsole, or
#     IDLE do not run in a terminal and hence it is not possible to do
#     correct auto-detection.
#     [default: 60] [currently: 60]
#
# display.max_seq_items : int or None
#     when pretty-printing a long sequence, no more then `max_seq_items`
#     will be printed. If items are omitted, they will be denoted by the
#     addition of "..." to the resulting string.
#
#     If set to None, the number of items to be printed is unlimited.
#     [default: 100] [currently: 100]
#
# display.memory_usage : bool, string or None
#     This specifies if the memory usage of a DataFrame should be displayed when
#     df.info() is called. Valid values True,False,'deep'
#     [default: True] [currently: True]
#
# display.multi_sparse : boolean
#     "sparsify" MultiIndex display (don't display repeated
#     elements in outer levels within groups)
#     [default: True] [currently: True]
#
# display.notebook_repr_html : boolean
#     When True, IPython notebook will use html representation for
#     pandas objects (if it is available).
#     [default: True] [currently: True]
#
# display.pprint_nest_depth : int
#     Controls the number of nested levels to process when pretty-printing
#     [default: 3] [currently: 3]
#
# display.precision : int
#     Floating point output precision (number of significant digits). This is
#     only a suggestion
#     [default: 6] [currently: 6]
#
# display.show_dimensions : boolean or 'truncate'
#     Whether to print out dimensions at the end of DataFrame repr.
#     If 'truncate' is specified, only print out the dimensions if the
#     frame is truncated (e.g. not display all rows and/or columns)
#     [default: truncate] [currently: truncate]
#
# display.unicode.ambiguous_as_wide : boolean
#     Whether to use the Unicode East Asian Width to calculate the display text
#     width.
#     Enabling this may affect to the performance (default: False)
#     [default: False] [currently: False]
#
# display.unicode.east_asian_width : boolean
#     Whether to use the Unicode East Asian Width to calculate the display text
#     width.
#     Enabling this may affect to the performance (default: False)
#     [default: False] [currently: False]
#
# display.width : int
#     Width of the display in characters. In case python/IPython is running in
#     a terminal this can be set to None and pandas will correctly auto-detect
#     the width.
#     Note that the IPython notebook, IPython qtconsole, or IDLE do not run in a
#     terminal and hence it is not possible to correctly detect the width.
#     [default: 80] [currently: 80]

# %%
from IPython.core.display import HTML
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Status</th>
#       <th>Date_Forcast_Start</th>
#       <th>Date_Opp_Creation</th>
#       <th>EndCl_Nr</th>
#       <th>EndCl_Name</th>
#       <th>EP</th>
#       <th>Date_Opp_End</th>
#       <th>Date_Last_Change</th>
#       <th>Date_Opp_Won</th>
#       <th>Debitor</th>
#       <th>Debitor_name</th>
#       <th>Date_Decision</th>
#       <th>Date_Last_Update</th>
#       <th>PC_L_3</th>
#       <th>PC_L_4</th>
#       <th>PC_L_5</th>
#       <th>PC_L_6</th>
#       <th>Sector</th>
#       <th>Segment</th>
#       <th>Service_Solution</th>
#       <th>Solution_Cluster</th>
#       <th>Solution_Line</th>
#       <th>Solution</th>
#       <th>Sub_Solution</th>
#       <th>Opp_Nr</th>
#       <th>Opp_Name</th>
#       <th>TOP_Account</th>
#       <th>SalesStage</th>
#       <th>Recurring_Indi</th>
#       <th>Anzahl_Opp</th>
#       <th>EUR_NetSales</th>
#       <th>EUR_Actuals</th>
#       <th>FC_current_FY</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Offen</td>
#       <td>17.07.2019</td>
#       <td>17.07.2019</td>
#       <td>60022731</td>
#       <td>Münchener Rückversicherungs-Gesellschaft Aktie...</td>
#       <td>Wolf, Thomas</td>
#       <td>17.07.2022</td>
#       <td>17.07.2019</td>
#       <td>#</td>
#       <td>60022731</td>
#       <td>Münchener Rückversicherungs-Gesellschaft Aktie...</td>
#       <td>17.07.2019</td>
#       <td>31.10.2019</td>
#       <td>0                     Law\n1      Financial Se...</td>
#       <td>Legal Corporate Services</td>
#       <td>Legal Corporate Services</td>
#       <td>Legal Corporate Services</td>
#       <td>Insurance</td>
#       <td>Financial Services</td>
#       <td>Law</td>
#       <td>Corporate Legal Services</td>
#       <td>Corporate Legal Services</td>
#       <td>Legal Housekeeping</td>
#       <td>Legal Housekeeping</td>
#       <td>75034132</td>
#       <td>Münchener Rückvers. - ArbR Beratung</td>
#       <td>X</td>
#       <td>Mündliche Zusage</td>
#       <td>Neu - mit Recurring Work in Folgejahren</td>
#       <td>1</td>
#       <td>EUR 30,000.00</td>
#       <td>EUR 0.00</td>
#       <td>EUR nan</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>